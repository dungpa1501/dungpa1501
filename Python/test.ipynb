# %%
import pandas as pd
from sqlalchemy import create_engine

# DEFINE THE DATABASE CREDENTIALS
username = 'sa'
password = 'GaLaXyNDNTTB126'
server = '10.20.30.116'
database = 'VISTA'
 
# PYTHON FUNCTION TO CONNECT TO THE MYSQL DATABASE AND
# RETURN THE SQLACHEMY ENGINE OBJECT
connection_string = f'mssql+pyodbc://{username}:{password}@{server}/{database}?driver=ODBC+Driver+17+for+SQL+Server'
 
# Establish the connection
engine = create_engine(connection_string)

query = '''
    select top 100 * from tblPOS_Sess where POSS_strStatus = 'A' order by POSS_dtmBusinessDate desc
'''

df = pd.read_sql(query,engine)

df = df.sort_values(by="POSS_dtmBusinessDate", ascending= False).reset_index()

df
# Out:
#    index  POSS_intPOSSessionNumber  User_intUserNo POSS_strUserName  \
# 0      0                    126705            6753   Tho Nguyen Thi
# 1      1                    126698            6728  Thuy Trinh Hong
#
#   POSS_strStatus POSS_dtmBusinessDate   POSS_dtmLogonDateTime  \
# 0              A           2024-10-23 2024-10-23 14:12:24.917
# 1              A           2024-10-23 2024-10-23 09:02:28.717
#
#   POSS_dtmLogoffDateTime POSS_dtmLastLockedDateTime  \
# 0                   None                       None
# 1                   None                       None
#
#    POSS_intCumulativeDownTimeSecs  ... POSS_intPOSLayoutAreaId  \
# 0                               0  ...                    None
# 1                               0  ...                    None
#
#   POSS_strCashDrawerWorkstation POSS_intCashDrawer  \
# 0                          None               None
# 1                          None               None
#
#    POSS_curTotalTipShareContribution  POSS_intNumOperatorVoids  \
# 0                               None                         0
# 1                               None                         0
#
#    POSS_curOperatorVoids  POSS_dtmCashupDateTime  POSS_dtmUndoCashupDateTime  \
# 0                    0.0                    None                        None
# 1                    0.0                    None                        None
#
#    User_intCashedUpByUserNo  User_intCashUpWitnessUserNo
# 0                      None                         None
# 1                      None                         None
#
# [2 rows x 93 columns]

# %%
from test2 import * 

dir(test2)

#print(testa(1,2))
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'a',
#  'b']
